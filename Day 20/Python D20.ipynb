# %%
# !pip install newspaper3k

# %%
# !pip install nltk

# %%
from newspaper import Article

# %%
article = Article('https://vnexpress.net/loi-nhuan-nganh-bia-giam-sau-vi-kiem-soat-nong-do-con-4722853.html')

# %%
article.download()
article.parse()

# %%
print(article.text)
# Out:
# Ngành bia, cùng hệ thống thương mại, nhà hàng ghi nhận doanh thu, lợi nhuận giảm 20% trong 2023, do chính sách kiểm soát nồng độ cồn.
#
# Thông tin trên được Hiệp hội Bia - Rượu - Nước giải khát Việt Nam (VBA) chia sẻ tại hội nghị chiều 15/3. Theo hiệp hội này, chính sách kiểm soát nồng độ cồn là một trong nguyên nhân khiến tiêu dùng bia giảm mạnh, nhất là ở kênh nhà hàng, quán ăn.
#
# Ước tính của hiệp hội này, ngành bia giảm 11% doanh thu, và 23% lợi nhuận trước thuế trong năm 2023. Trước đó, năm 2022, ngành này cũng chịu tăng trưởng âm 7%.
#
# Chẳng hạn, lợi nhuận hai "ông lớn" ngành bia giảm sâu trong 2023. Theo kết quả kinh doanh của Tổng công ty cổ phần Bia - Rượu - Nước giải khát Sài Gòn (Sabeco), lợi nhuận sau thuế khoảng 4.255 tỷ đồng, giảm 23%. Nếu không tính giai đoạn đỉnh dịch 2021, con số này chạm đáy kể từ năm 2016.
#
# Tương tự, lãi năm ngoái của Tổng công ty cổ phần Bia - Rượu - Nước giải khát Hà Nội (Habeco) giảm 30% so với 2022, còn 355 tỷ đồng.
#
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download the necessary resource
nltk.download('averaged_perceptron_tagger')

data = 'Tôi thích học AI và Toán'

tokenization = word_tokenize(data)

result = nltk.pos_tag(tokenization)

print(result)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Tôi', 'NNP'), ('thích', 'NN'), ('học', 'NN'), ('AI', 'NNP'), ('và', 'NN'), ('Toán', 'NNP')]

# %%
import newspaper

# %%
article = Article('https://vnexpress.net/vay-ngan-hang-tren-100-trieu-co-the-phai-cap-thong-tin-nguoi-lien-quan-4722857.html')

# %%
article.download()
article.parse()

# %%
article.text
# Out:
# 'Khách hàng có thể phải gửi thông tin người liên quan (cá nhân, tổ chức) khi vay ngân hàng trên 100 triệu đồng.\n\nĐiều kiện này được Ngân hàng Nhà nước đưa ra khi sửa Thông tư 39 quy định về cho vay của tổ chức tín dụng, chi nhánh ngân hàng nước ngoài.\n\nHiện, khách vay vốn chỉ cần nộp hồ sơ đăng ký, có tài sản đảm bảo và không cần cung cấp thông tin của người có liên quan cho ngân hàng.\n\nNhưng tại dự thảo mới, Ngân hàng Nhà nước bổ sung thêm điều kiện dựa trên giá trị khoản vay. Theo đó, cơ quan này đề xuất khách hàng khi vay trên 100 triệu đồng sẽ phải cung cấp thông tin người có liên quan, ngoài hồ sơ đề nghị, phương án dùng vốn, tài sản đảm bảo.\n\nNếu người liên quan là cá nhân, thông tin kèm theo gồm họ và tên, số định danh cá nhân, quốc tịch, hộ chiếu và mối quan hệ với khách vay. Trường hợp là tổ chức, thông tin phải khai như tên, mã số doanh nghiệp, địa chỉ, số Giấy chứng nhận đăng ký, người đại diện theo pháp luật...\n\nNgược lại, với khoản vay nhỏ dưới 100 triệu đồng, 
# ...

# %%
article.nlp()
article.summary
# Out:
# 'Khách hàng có thể phải gửi thông tin người liên quan (cá nhân, tổ chức) khi vay ngân hàng trên 100 triệu đồng.\nĐiều kiện này được Ngân hàng Nhà nước đưa ra khi sửa Thông tư 39 quy định về cho vay của tổ chức tín dụng, chi nhánh ngân hàng nước ngoài.\nHiện, khách vay vốn chỉ cần nộp hồ sơ đăng ký, có tài sản đảm bảo và không cần cung cấp thông tin của người có liên quan cho ngân hàng.\nNhưng tại dự thảo mới, Ngân hàng Nhà nước bổ sung thêm điều kiện dựa trên giá trị khoản vay.\nTheo đó, cơ quan này đề xuất khách hàng khi vay trên 100 triệu đồng sẽ phải cung cấp thông tin người có liên quan, ngoài hồ sơ đề nghị, phương án dùng vốn, tài sản đảm bảo.'

# %%
article.publish_date

# %%
data = article.text

tokenization = word_tokenize(data)

result = nltk.pos_tag(tokenization)

print(result)
# Out:
# [('Khách', 'NNP'), ('hàng', 'NN'), ('có', 'NN'), ('thể', 'NN'), ('phải', 'NN'), ('gửi', 'NN'), ('thông', 'NN'), ('tin', 'NN'), ('người', 'JJ'), ('liên', 'NN'), ('quan', 'NN'), ('(', '('), ('cá', 'JJ'), ('nhân', 'NN'), (',', ','), ('tổ', 'VB'), ('chức', 'NN'), (')', ')'), ('khi', 'NN'), ('vay', 'NN'), ('ngân', 'JJ'), ('hàng', 'NN'), ('trên', 'NN'), ('100', 'CD'), ('triệu', 'NN'), ('đồng', 'NN'), ('.', '.'), ('Điều', 'CC'), ('kiện', 'JJ'), ('này', 'JJ'), ('được', 'NN'), ('Ngân', 'NNP'), ('hàng', 'NN'), ('Nhà', 'NNP'), ('nước', 'CC'), ('đưa', 'NNP'), ('ra', 'VBP'), ('khi', 'NN'), ('sửa', 'NN'), ('Thông', 'NNP'), ('tư', 'VBZ'), ('39', 'CD'), ('quy', 'NN'), ('định', 'NNP'), ('về', 'NN'), ('cho', 'NN'), ('vay', 'NN'), ('của', 'NN'), ('tổ', 'NN'), ('chức', 'NN'), ('tín', 'NN'), ('dụng', 'NN'), (',', ','), ('chi', 'JJ'), ('nhánh', 'FW'), ('ngân', 'JJ'), ('hàng', 'NN'), ('nước', 'NN'), ('ngoài', 'NN'), ('.', '.'), ('Hiện', 'NNP'), (',', ','), ('khách', 'VBD'), ('vay', 'JJ'), ('vốn', 'NN'), ('
# ...
