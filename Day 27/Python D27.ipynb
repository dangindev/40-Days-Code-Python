# %%
# !pip install underthesea
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 23.1 MB/s eta 0:00:00
# ...

# %%
text = "Công cụ Suno AI nhanh chóng nhận được sự chú ý từ người dùng khi có thể tạo bài hát chỉ với vài câu lệnh. Phiên bản mới nhất V3 Alpha mới được giới thiệu cuối tháng 2, có bản miễn phí với 10 bài hát mỗi ngày."

# %%
from underthesea import pos_tag, classify, sentiment, sent_tokenize, word_tokenize
result1 = pos_tag(text)
result2 = classify(text)
result3 = sentiment(text)
result4 = sent_tokenize(text)
result5 = word_tokenize(text)

print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
# Out:
# 2024-04-08 07:15:01,579 https://github.com/undertheseanlp/playground/releases/download/1.3.x/tc_svm_vntc_20201228.zip not found in cache, downloading to /tmp/tmpp45gvklv
# 100%|██████████| 75578053/75578053 [00:01<00:00, 64537704.59B/s]
# 2024-04-08 07:15:02,933 copying /tmp/tmpp45gvklv to cache at /root/.underthesea/models/tc_svm_vntc_20201228.zip
# 2024-04-08 07:15:03,127 removing temp file /tmp/tmpp45gvklv
# 2024-04-08 07:15:20,805 https://github.com/undertheseanlp/playground/releases/download/1.3.x/sa_svm_vlsp2016-sa_20210107.zip not found in cache, downloading to /tmp/tmp6bl0ntqt
# 100%|██████████| 2234880/2234880 [00:00<00:00, 36788143.53B/s]
# 2024-04-08 07:15:21,041 copying /tmp/tmp6bl0ntqt to cache at /root/.underthesea/models/sa_svm_vlsp2016-sa_20210107.zip
# 2024-04-08 07:15:21,047 removing temp file /tmp/tmp6bl0ntqt
# ...
